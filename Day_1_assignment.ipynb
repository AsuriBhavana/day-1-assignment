# %% [markdown]
# <a href="https://colab.research.google.com/github/AsuriBhavana/day-1-assignment/blob/main/Day_1_assignment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("RAINBOW")
# Out:
# RAINBOW

# %%
print("LETS UPGRADE")
# Out:
# LETS UPGRADE

# %%
CP=int(input())
SP=int(input())
if (CP>SP):
    print("Loss")
elif (SP>CP):
    print("Profit")
else:
    print("Neither")
# Out:
# 20
# 30
# Profit

# %%
Euro=float(input())
Rupees=Euro*80
print(Rupees,"Rupees")
# Out:
# 2
# 160.0 Rupees
